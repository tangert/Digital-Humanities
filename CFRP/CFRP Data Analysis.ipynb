# %% [markdown]
# # CFRP Data Analysis
#
# This is where we will clean and format the data from the CFRP API to use in our data visualization.

# %%
# imports
import pandas as pd
import json
import tabulate
from IPython.display import HTML, display

# %% [markdown]
# ## Data format
#
# The given data format from the endpoint `http://api.cfregisters.org/play_ticket_sales` with params `genre=genre=eq.comédie` and `play_performance_id=lt.1000`

# %%
{
    "play_performance_id": 437, 
    "seating_capacity": 6,
    "name": "Premières Places",
    "title": "Avocat Patelin (L')",
    "author": "Brueys (David-Augustin de)",
    "genre": "comédie",
    "date": "1779-03-09",
    "total_sold": 35
}
# Out:
# {'author': 'Brueys (David-Augustin de)',
#  'date': '1779-03-09',
#  'genre': 'comédie',
#  'name': 'Premières Places',
#  'play_performance_id': 437,
#  'seating_capacity': 6,
#  'title': "Avocat Patelin (L')",
#  'total_sold': 35}

# %% [markdown]
# ### What we need:
#
# Because our interactive visualization (at least the demo) allows the user to scrub through monthly ticket sales data for each play, we need to aggregate the total amount of tickets sold for each seating area for each play for each month of the year (if possible).
#
# *pic here of visualization mock up*
#
# Not every play is shown every month, so we will calculate the **most popular plays** for **each month** in a given year, and visualize the **sales data for each seating area** for those given plays.

# %% [markdown]
# ### Process
#
# We will take the JSON response from the API and turn it into a Pandas data frame for easy aggregation. We will follow a 3 step process to get our data into the format we need.
#
# So first we will convert the JSON format as seen above into a CSV like this:

# %% [markdown]
# **[play_performance_id,title,author,name,date,total_sold]**

# %% [markdown]
# Then, after grouping by month and play, then averaging the sales data, we will use this format in the visualization:

# %% [markdown]
# **[title, seating_area_1, seating_area_2, seating_area_3, seating_area_4, seating_area_5]**

# %% [markdown]
# Where each row is the month of the year.

# %% [markdown]
# ## Just show me the code

# %%
# Import the JSON data and convert to pandas data frame
with open('Data/CFRP-data.json', 'r') as f:
    data = json.load(f)

# create the data frame
df = pd.DataFrame(data)

# %%
# convenience dictionary for printing
int2mon = {
    1: "January",
    2: "February",
    3: "March",
    4: "April",
    5: "May",
    6: "June",
    7: "July",
    8: "August",
    9: "September",
    10: "October",
    11: "November",
    12: "December"
}

# %%
def parse_date(date):
    """ 
    Converts a string formatted date in an easy-to-access date array.
    
        Example input: "1776-07-04"
        Example output: [1776, 7, 4]
    """
    
    #splits the input date string into an array
    inp = date.split('-')
    
    # converts each element into an integer
    formatted = [int(d) for d in inp]
    
    return formatted

# %%
"""
    we need to get the most popular show from each month for each year
    steps:
    1. group by month and year
    
        aggregate by date
        
        for each date:
            convert to parsed object
            access month
"""

# Conver the string into date object
formatted_date_col = df['date'].apply(parse_date)

# grab only the month from the new date column
months_col = formatted_date_col.apply(lambda d: d[1])
years_col = formatted_date_col.apply(lambda d: d[0])

# rename the column to months
df.rename(columns={'date': 'month'}, inplace=True)

# apply the transformed columns
df['month'] = months_col
df['year'] = years_col

# %%
df
# Out:
#                                                  author  month    genre  \
# 0                            Brueys (David-Augustin de)      3  comédie
# 1                            Brueys (David-Augustin de)      3  comédie
# 2                            Brueys (David-Augustin de)      3  comédie
# 3                            Brueys (David-Augustin de)      3  comédie
# 4                            Brueys (David-Augustin de)      3  comédie
# 5     Molière (Jean-Baptiste Poquelin dit) - arrangé...      3  comédie
# 6     Molière (Jean-Baptiste Poquelin dit) - arrangé...      3  comédie
# 7     Molière (Jean-Baptiste Poquelin dit) - arrangé...      3  comédie
# 8     Molière (Jean-Baptiste Poquelin dit) - arrangé...      3  comédie
# 9     Molière (Jean-Baptiste Poquelin dit) - arrangé...      3  comédie
# 10                               Legrand (Marc-Antoine)      6  comédie
# 11                               Legrand (Marc-Antoine)      6  comédie
# 12                               Legrand (Marc-Antoine)      6  comédie
# 13                               Legrand (Marc-Antoine)      6  comédie
# 14    Molière (Jean-Baptiste Poquelin dit) - arrangé...      6  comédie
# 15    Molière (Jean-Baptiste Poquelin dit) - arrangé...      6  comédie
# 16    Molière (Jean-Baptiste Poquelin dit) - arrangé...      6  comédie
# 17    Molière (Jean-Baptiste Poquelin dit) - arrangé...      6  comédie
# 18                                La Fontaine (Jean de)      2  comédie
# 19                                La Fontaine (Jean de)      2  comédie
# 20                                La Fontaine (Jean de)      2  comédie
# 21                                La Fontaine (Jean de)      2  comédie
# 22                                La Fontaine (Jean de)      2  comédie
# 23                                La Fontaine (Jean de)      2  comédie
# 24    Molière (Jean-Baptiste Poquelin dit) - arrangé...      2  comédie
# 25    Molière (Jean-Baptiste Poquelin dit) - arrangé...      2  comédie
# 26    Molière (Jean-Baptiste Poquelin dit) - arrangé...      2  comédie
# 27    Molière (Jean-Baptiste Poquelin dit) - arrangé...      2  comédie
# 28    Molière (Jean-Baptiste Poquelin dit) - arrangé...      2  comédie
# 29    Molière (Jean-Baptiste Poquelin dit) - arrangé...      2  comédie
# ...                                                 ...    ...      ...
# 3075                                           Dorvigny      1  comédie
# 3076                                           Dorvigny      1  comédie
# 3077                                           Dorvigny      1  comédie
# 3078                                           Dorvigny      1  comédie
# 3079                                           Dorvigny      1  comédie
# 3080                                           Dorvigny      1  comédie
# 3081                                           Dorvigny      1  comédie
# 3082                                           Dorvigny      1  comédie
# 3083                                           Dorvigny      1  comédie
# 3084                                           Dorvigny      1  comédie
# 3085                      Dancourt (Florent Carton dit)      5  comédie
# 3086                      Dancourt (Florent Carton dit)      5  comédie
# 3087                      Dancourt (Florent Carton dit)      5  comédie
# 3088                      Dancourt (Florent Carton dit)      5  comédie
# 3089                      Dancourt (Florent Carton dit)      5  comédie
# 3090                      Dancourt (Florent Carton dit)      5  comédie
# 3091                      Dancourt (Florent Carton dit)      5  comédie
# 3092                      Dancourt (Florent Carton dit)      5  comédie
# 3093                            Regnard (Jean-François)      2  comédie
# 3094                            Regnard (Jean-François)      2  comédie
# 3095                            Regnard (Jean-François)      2  comédie
# 3096                            Regnard (Jean-François)      2  comédie
# 3097                            Regnard (Jean-François)      2  comédie
# 3098                            Regnard (Jean-François)      2  comédie
# 3099                      Dancourt (Florent Carton dit)      2  comédie
# 3100                      Dancourt (Florent Carton dit)      2  comédie
# 3101                      Dancourt (Florent Carton dit)      2  comédie
# 3102                      Dancourt (Florent Carton dit)      2  comédie
# 3103                      Dancourt (Florent Carton dit)      2  comédie
# 3104                      Dancourt (Florent Carton dit)      2  comédie
#
#                     name  play_performance_id  seating_capacity  \
# 0       Premières Places                  437                 6
# 1        Secondes Places                  437                 6
# 2     Places de Parterre                  437                 6
# 3          Petites Loges                  437                 6
# 4      Troisièmes Places                  437                 6
# 5       Premières Places                  436                 6
# 6        Secondes Places                  436                 6
# 7     Places de Parterre                  436                 6
# 8          Petites Loges                  436                 6
# 9      Troisièmes Places                  436                 6
# 10      Premières Places                  920                 6
# 11       Secondes Places                  920                 6
# 12     Troisièmes Places                  920                 6
# 13    Places de Parterre                  920                 6
# 14      Premières Places                  919                 6
# 15       Secondes Places                  919                 6
# 16     Troisièmes Places                  919                 6
# 17    Places de Parterre                  919                 6
# 18      Secondes Loges 3                  623                 6
# 19         Petites Loges                  623                 6
# 20      Premières Places                  623                 6
# 21       Secondes Places                  623                 6
# 22     Troisièmes Places                  623                 6
# 23    Places de Parterre                  623                 6
# 24      Secondes Loges 3                  622                 6
# 25         Petites Loges                  622                 6
# 26      Premières Places                  622                 6
# 27       Secondes Places                  622                 6
# 28     Troisièmes Places                  622                 6
# 29    Places de Parterre                  622                 6
# ...                  ...                  ...               ...
# 3075   Premières Loges 2                  217                 6
# 3076   Premières Loges 4                  217                 6
# 3077    Secondes Loges 2                  217                 6
# 3078    Secondes Loges 3                  217                 6
# 3079    Troisièmes Loges                  217                 6
# 3080       Petites Loges                  217                 6
# 3081    Premières Places                  217                 6
# 3082     Secondes Places                  217                 6
# 3083   Troisièmes Places                  217                 6
# 3084  Places de Parterre                  217                 6
# 3085    Premières Places                  894                 6
# 3086     Secondes Places                  894                 6
# 3087   Troisièmes Places                  894                 6
# 3088  Places de Parterre                  894                 6
# 3089    Premières Places                  893                 6
# 3090     Secondes Places                  893                 6
# 3091   Troisièmes Places                  893                 6
# 3092  Places de Parterre                  893                 6
# 3093    Secondes Loges 3                  367                 6
# 3094       Petites Loges                  367                 6
# 3095    Premières Places                  367                 6
# 3096     Secondes Places                  367                 6
# 3097   Troisièmes Places                  367                 6
# 3098  Places de Parterre                  367                 6
# 3099    Secondes Loges 3                  366                 6
# 3100       Petites Loges                  366                 6
# 3101    Premières Places                  366                 6
# 3102     Secondes Places                  366                 6
# 3103   Troisièmes Places                  366                 6
# 3104  Places de Parterre                  366                 6
#
#                                                   title  total_sold  year
# 0                                   Avocat Patelin (L')          35  1779
# 1                                   Avocat Patelin (L')          62  1779
# 2                                   Avocat Patelin (L')         309  1779
# 3                                   Avocat Patelin (L')           2  1779
# 4                                   Avocat Patelin (L')          30  1779
# 5                                 Festin de Pierre (Le)          35  1779
# 6                                 Festin de Pierre (Le)          62  1779
# 7                                 Festin de Pierre (Le)         309  1779
# 8                                 Festin de Pierre (Le)           2  1779
# 9                                 Festin de Pierre (Le)          30  1779
# 10                              Épreuve réciproque (L')          38  1779
# 11                              Épreuve réciproque (L')          71  1779
# 12                              Épreuve réciproque (L')          27  1779
# 13                              Épreuve réciproque (L')         215  1779
# 14                                Festin de Pierre (Le)          38  1779
# 15                                Festin de Pierre (Le)          71  1779
# 16                                Festin de Pierre (Le)          27  1779
# 17                                Festin de Pierre (Le)         215  1779
# 18                                       Florentin (Le)           1  1780
# 19                                       Florentin (Le)           1  1780
# 20                                       Florentin (Le)          21  1780
# 21                                       Florentin (Le)          46  1780
# 22                                       Florentin (Le)          21  1780
# 23                                       Florentin (Le)         221  1780
# 24                                Festin de Pierre (Le)           1  1780
# 25                                Festin de Pierre (Le)           1  1780
# 26                                Festin de Pierre (Le)          21  1780
# 27                                Festin de Pierre (Le)          46  1780
# 28                                Festin de Pierre (Le)          21  1780
# 29                                Festin de Pierre (Le)         221  1780
# ...                                                 ...         ...   ...
# 3075  Étrennes de l'amitié, de l'amour et de la natu...           1  1780
# 3076  Étrennes de l'amitié, de l'amour et de la natu...           1  1780
# 3077  Étrennes de l'amitié, de l'amour et de la natu...           2  1780
# 3078  Étrennes de l'amitié, de l'amour et de la natu...           6  1780
# 3079  Étrennes de l'amitié, de l'amour et de la natu...           1  1780
# 3080  Étrennes de l'amitié, de l'amour et de la natu...           8  1780
# 3081  Étrennes de l'amitié, de l'amour et de la natu...         185  1780
# 3082  Étrennes de l'amitié, de l'amour et de la natu...         101  1780
# 3083  Étrennes de l'amitié, de l'amour et de la natu...         130  1780
# 3084  Étrennes de l'amitié, de l'amour et de la natu...         450  1780
# 3085  Vacances (Les) / Les Vacances des procureurs (...          18  1779
# 3086  Vacances (Les) / Les Vacances des procureurs (...          35  1779
# 3087  Vacances (Les) / Les Vacances des procureurs (...           6  1779
# 3088  Vacances (Les) / Les Vacances des procureurs (...         100  1779
# 3089                           Chevalier à la mode (Le)          18  1779
# 3090                           Chevalier à la mode (Le)          35  1779
# 3091                           Chevalier à la mode (Le)           6  1779
# 3092                           Chevalier à la mode (Le)         100  1779
# 3093                                Retour imprévu (Le)           1  1778
# 3094                                Retour imprévu (Le)           1  1778
# 3095                                Retour imprévu (Le)          21  1778
# 3096                                Retour imprévu (Le)          53  1778
# 3097                                Retour imprévu (Le)           9  1778
# 3098                                Retour imprévu (Le)         196  1778
# 3099                           Chevalier à la mode (Le)           1  1778
# 3100                           Chevalier à la mode (Le)           1  1778
# 3101                           Chevalier à la mode (Le)          21  1778
# 3102                           Chevalier à la mode (Le)          53  1778
# 3103                           Chevalier à la mode (Le)           9  1778
# 3104                           Chevalier à la mode (Le)         196  1778
#
# [3105 rows x 9 columns]

# %%
# each year in the dataset
years = df.year.unique()

# %%
"""
    will contain a dataframe for each year of data, each one organized by month
    
    export as 3 different csv files, one for each year
    
    within each file:
"""

# all data
data_by_years = {}

# most popular data
most_popular_data = {}

# set the year keys and the relevant dataframes
for y in years:
    data_by_years[y] = df[df['year'] == y].copy()
    
    # set empty objects
    most_popular_data[y] = {}

# group each year's data by month and play
# find the most popular play each month

# first, go through each year
for year in data_by_years:
    
    data = data_by_years[year]
    
    # separate each year's data bymonth
    months = data.groupby('month', as_index=False)
    
    print("*******************")
    print("Year: {}".format(year))
    print("*******************\n")
    
     # Store the most popular play object
    most_popular_play = {}
    max_sales = 0
        
    for m in months:
        
        month = m[0]
        print("Month: {}".format(int2mon[month]))
        
        # separate each month by the plays
        plays = m[1].groupby('title', as_index=False)
        
        
        # Find the most popular play
        for p in plays:
            
#             print(p[0])
            seat_types = p[1].groupby('name', as_index=False)
            total_sales = p[1]['total_sold'].sum()
            
            if total_sales > max_sales:
                max_sales = total_sales
                
                # set the most popular play object based on the total sales
                most_popular_play = p
        
#         print("Most popular play: {}".format(most_popular_play[0]))
        # Store the most popular data formatted by seating area name for each month
        most_popular_data[year][month] = most_popular_play[1].groupby('name')
    print("Most popular play: {}".format(most_popular_play[0]))

print("\n\n\n")
# Out:
# *******************
# Year: 1779
# *******************
#
# Month: January
# Month: February
# Month: March
# Month: April
# Month: May
# Month: June
# Month: July
# Month: December
# Most popular play: Muses rivales ou l'Apothéose de Voltaire (Les)
# *******************
# Year: 1780
# *******************
#
# Month: January
# Month: February
# Month: March
# Most popular play: Étrennes de l'amitié, de l'amour et de la nature (Les)
# *******************
# Year: 1778
# *******************
#
# Month: January
# Month: February
# Month: March
# Month: April
# Month: May
# Month: June
# Most popular play: Homme personnel (L')

# %%
for year in most_popular_data:
    
    print("Year: {}".format(year))
    yearly_data = most_popular_data[year]

    for month in yearly_data.keys():
        
        print("Month: ", int2mon[month])
        
        for area_data in yearly_data[month]:
            
            print("Seating area: {}".format(area_data[0]))
#             print("Tickets sold: {}".format(area_data[1]['total_sold']))
            print("\n")
        
        print("\n\n")
# Out:
# Year: 1779
# Month:  January
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Month:  February
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Loges 1
#
#
# Seating area: Premières Loges 2
#
#
# Seating area: Premières Loges 3
#
#
# Seating area: Premières Loges 4
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 2
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Loges
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Month:  March
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Loges 2
#
#
# Seating area: Premières Loges 4
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 1
#
#
# Seating area: Secondes Loges 2
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Month:  April
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Loges 4
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 2
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Loges
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Month:  May
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Loges 2
#
#
# Seating area: Premières Loges 3
#
#
# Seating area: Premières Loges 4
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 2
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Month:  June
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Loges 2
#
#
# Seating area: Premières Loges 4
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Month:  July
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Loges 1
#
#
# Seating area: Premières Loges 2
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Month:  December
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 2
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Year: 1780
# Month:  January
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Loges 2
#
#
# Seating area: Premières Loges 4
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 2
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Loges
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Month:  February
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Loges 2
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 2
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Month:  March
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Year: 1778
# Month:  January
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Month:  February
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Loges 1
#
#
# Seating area: Premières Loges 2
#
#
# Seating area: Premières Loges 3
#
#
# Seating area: Premières Loges 4
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 1
#
#
# Seating area: Secondes Loges 2
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Loges
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Month:  March
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Loges 2
#
#
# Seating area: Premières Loges 4
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 2
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Month:  April
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Loges 2
#
#
# Seating area: Premières Loges 4
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 2
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Month:  May
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Loges 2
#
#
# Seating area: Premières Loges 4
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Loges 2
#
#
# Seating area: Secondes Loges 3
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Places
#
#
#
#
#
# Month:  June
# Seating area: Petites Loges
#
#
# Seating area: Places de Parterre
#
#
# Seating area: Premières Places
#
#
# Seating area: Secondes Places
#
#
# Seating area: Troisièmes Places

# %% [markdown]
# ### Collecting data from specific play, not just most popular (because of differences in seating arrangements...)

# %%
"""
    will contain a dataframe for each year of data, each one organized by month
    export as 3 different csv files, one for each year
    within each file:
"""

from collections import defaultdict

# all data
data_by_years = {}

#export dict
data_to_export = {}

# set the year keys and the relevant dataframes
for y in years:
    data_by_years[y] = df[df['year'] == y].copy()
    data_to_export[int(y)] = {}

# group each year's data by month and play
# find the most popular play each month

# first, go through each year
for year in data_by_years:
    
    print("*******************")
    print("Year: {}".format(year))
    print("*******************\n")
    
    data = data_by_years[year]
    
    #separate by plays
    plays = data.groupby('title', as_index=False)    
    
    for p in plays:
        if p[0] == "Muses rivales ou l'Apothéose de Voltaire (Les)":
            monthly_data = p[1].groupby('month')
            for m in monthly_data:
                print(m[0])
        
#     for m in months:
        
#         month = m[0]
#         plays = m[1].groupby('title', as_index=False)
        
            
#             # set the indices:
#         for p in plays:
#             data_to_export[int(year)][month] = {}
        
#         # Find the most popular play
#         for p in plays:
            
#             play_name = p[0]
#             seat_types = p[1].groupby('name', as_index=True)
            
#             relevant_seat_data = {}
            
#             for d in seat_types:            
#                 relevant_seat_data[d[0]] = d[1]['total_sold']
            
#             data_to_export[int(year)][month][play_name] = relevant_seat_data   
        
        # For collecting every play's data.
        
#         # set the indices:
#         for p in plays:
#             data_to_export[int(year)][month] = {}
        
#         # Find the most popular play
#         for p in plays:
            
#             play_name = p[0]
#             seat_types = p[1].groupby('name', as_index=True)
            
#             relevant_seat_data = {}
            
#             for d in seat_types:            
#                 relevant_seat_data[d[0]] = d[1]['total_sold']
            
#             data_to_export[int(year)][month][play_name] = relevant_seat_data

        ##Collecting a specific play's data
# Out:
# *******************
# Year: 1779
# *******************
#
# 2
# 3
# *******************
# Year: 1780
# *******************
#
# *******************
# Year: 1778
# *******************
