# %%
import logging
import json
import pandas as pd
import numpy as np

# NLP
import gensim
import spacy
import nltk

from sklearn.decomposition import PCA
from matplotlib import pyplot as plt

# %% [markdown]
# # Convert the religious CSVs into dataframes

# %%
old_t_df = pd.read_csv("../data/old-testament-verses.csv")
new_t_df = pd.read_csv("../data/new-testament-verses.csv")
quran_df = pd.read_csv("../data/quran-verses.csv")

# %% [markdown]
# # Samples of the data

# %%
old_t_df.head(3)
# Out:
#    VerseID  BookID  Chapter  VerseNum  OsisRef  \
# 0        1       1        1         1  Gen.1.1
# 1        2       1        1         2  Gen.1.2
# 2        3       1        1         3  Gen.1.3
#
#                                            VerseText
# 0  In the beginning God created the heaven and th...
# 1  And the earth was without form, and void; and ...
# 2  And God said, Let there be light: and there wa...

# %%
new_t_df.head(3)
# Out:
#    VerseID  BookID  Chapter  VerseNum   OsisRef  \
# 0    23146      40        1         1  Matt.1.1
# 1    23147      40        1         2  Matt.1.2
# 2    23148      40        1         3  Matt.1.3
#
#                                            VerseText
# 0  The book of the generation of Jesus Christ, th...
# 1  Abraham begat Isaac; and Isaac begat Jacob; an...
# 2  And Judas begat Phares and Zara of Thamar; and...

# %%
quran_df.head(3)
# Out:
#    DatabaseID  SuraID  VerseID  \
# 0          59       1        1
# 1          59       1        2
# 2          59       1        3
#
#                                             AyahText
# 0  In the name of Allah, Most Gracious, Most Merc...
# 1  Praise be to Allah, the Cherisher and Sustaine...
# 2                      Most Gracious, Most Merciful;

# %% [markdown]
# # Cleaning and prep for VSM
# Preprocess using genism utils.

# %%
old_t_verses = list(old_t_df["VerseText"])
old_t_documents = [gensim.utils.simple_preprocess(v) for v in old_t_verses]

# %%
new_t_verses = list(new_t_df["VerseText"])
new_t_documents = [gensim.utils.simple_preprocess(v) for v in new_t_verses]

# %%
quran_verses = list(quran_df["AyahText"])
quran_documents = [gensim.utils.simple_preprocess(v) for v in quran_verses]

# %% [markdown]
# ## Training the models individually for each text

# %%
# Global hyper parameters
hp = {
    "size": 150, # size of the one-hot-encoded word vectors
    "window": 10, # context size
    "min_count": 2,
    "workers": 10
}

# %%
# Have input word, then use nltk / spacy to get its lemma and test all of the lemmas.
# then take an average rating from all of the lemmas
word_sample = "marry"

# %%
# helper function for printing words form results of model
def get_res(res):
    return [d[0] for d in res]

# %% [markdown]
# ## Old Testament

# %%
old_t_model = gensim.models.Word2Vec(
        old_t_documents,
        size=hp["size"],
        window=hp["window"],
        min_count=hp["min_count"],
        workers=hp["workers"])

old_t_model.train(old_t_documents, total_examples=len(old_t_documents), epochs=10)
# Out:
# (3906897, 5953120)

# %%
pca = PCA(n_components=3)

old_t_X = old_t_model[old_t_model.wv.vocab]
old_t_result = pca.fit_transform(old_t_X)

new_t_X = new_t_model[new_t_model.wv.vocab]
new_t_result = pca.fit_transform(new_t_X)

quran_X = quran_model[quran_model.wv.vocab]
quran_result = pca.fit_transform(quran_X)
# Out:
# /Users/tylerangert/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/tylerangert/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /Users/tylerangert/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':

# %%
wv_dict = {}
wv_dict["old_t"] = {}
wv_dict["new_t"] = {}
wv_dict["quran"] = {}

for i, word in enumerate(list(old_t_model.wv.vocab)):
    wv_dict["old_t"][word] = [float(old_t_result[i][0]),float(old_t_result[i][1]),float(old_t_result[i][2])]
    

for i, word in enumerate(list(new_t_model.wv.vocab)):
    wv_dict["new_t"][word] = [float(new_t_result[i][0]),float(new_t_result[i][1]),float(new_t_result[i][2])]
    
for i, word in enumerate(list(quran_model.wv.vocab)):
    wv_dict["quran"][word] = [float(quran_result[i][0]),float(quran_result[i][1]),float(quran_result[i][2])]

# %%
wv_dict
with open('word_vectors-3.json', 'w') as fp:
    json.dump(wv_dict, fp)

# %%
# create a scatter plot of the projection
plt.scatter(old_t_result[:, 0], old_t_result[:, 1])
words = list(old_t_model.wv.vocab)
for i, word in enumerate(words):
    plt.annotate(word, xy=(old_t_result[i, 0], old_t_result[i, 1]))

# %%
plt.rcParams['figure.figsize'] = (30,15)
plt.show()

# %%
old_t_res = old_t_model.wv.most_similar (positive=word_sample)
old_t_res
# Out:
# [('loving', 0.8498883247375488),
#  ('eve', 0.8497138619422913),
#  ('laboureth', 0.841971755027771),
#  ('gathrimmon', 0.8383175730705261),
#  ('malcham', 0.8371787667274475),
#  ('shubael', 0.8212587237358093),
#  ('condemneth', 0.8185698986053467),
#  ('shuhamites', 0.8185401558876038),
#  ('reu', 0.8184724450111389),
#  ('keros', 0.818000078201294)]

# %%
print(get_res(old_t_res))
# Out:
# ['loving', 'eve', 'laboureth', 'gathrimmon', 'malcham', 'shubael', 'condemneth', 'shuhamites', 'reu', 'keros']

# %% [markdown]
# ## New Testament

# %%
new_t_model = gensim.models.Word2Vec(
        new_t_documents,
        size=hp["size"],
        window=hp["window"],
        min_count=hp["min_count"],
        workers=hp["workers"])

new_t_model.train(new_t_documents, total_examples=len(new_t_documents), epochs=10)
# Out:
# (1162574, 1762370)

# %%
new_t_res = new_t_model.wv.most_similar (positive=word_sample)
new_t_res
# Out:
# [('testament', 0.8535803556442261),
#  ('ripe', 0.8270993828773499),
#  ('less', 0.8074337840080261),
#  ('invisible', 0.8060460686683655),
#  ('elect', 0.798071563243866),
#  ('last', 0.7979719042778015),
#  ('sown', 0.7977509498596191),
#  ('mystery', 0.7958735227584839),
#  ('adam', 0.7939164042472839),
#  ('theirs', 0.7928258776664734)]

# %%
print(get_res(new_t_res))
# Out:
# ['testament', 'ripe', 'less', 'invisible', 'elect', 'last', 'sown', 'mystery', 'adam', 'theirs']

# %% [markdown]
# # Quran

# %%
# NEW TESTAMENT
quran_model = gensim.models.Word2Vec(
        quran_documents,
        size=hp["size"],
        window=hp["window"],
        min_count=hp["min_count"],
        workers=hp["workers"])

quran_model.train(quran_documents, total_examples=len(quran_documents), epochs=10)
# Out:
# (1093932, 1682410)

# %%
quran_res = quran_model.wv.most_similar (positive=word_sample)
quran_res
# Out:
# [('writing', 0.9285460114479065),
#  ('maintenance', 0.9220064878463745),
#  ('support', 0.9072032570838928),
#  ('flog', 0.9050097465515137),
#  ('bond', 0.8985353112220764),
#  ('middle', 0.8957507610321045),
#  ('lower', 0.8946830034255981),
#  ('ties', 0.8932483792304993),
#  ('silver', 0.8932350873947144),
#  ('impure', 0.8911339044570923)]

# %%
print(get_res(quran_res))
# Out:
# ['writing', 'maintenance', 'support', 'flog', 'bond', 'middle', 'lower', 'ties', 'silver', 'impure']

# %% [markdown]
# ## Getting funky
# Let's do some algebra...

# %%
# most_similar_cosmul
# most_similar

# %%
old_t_model.wv.most_similar_cosmul(positive=['god', 'woman'], negative=['man'])
# Out:
# [('servant', 0.7991612553596497),
#  ('blessing', 0.7971335649490356),
#  ('trouble', 0.7964797616004944),
#  ('sister', 0.7916172742843628),
#  ('prayer', 0.7876102328300476),
#  ('queen', 0.7859851717948914),
#  ('supplication', 0.7846454977989197),
#  ('affliction', 0.7826079726219177),
#  ('misery', 0.7778688073158264),
#  ('handmaid', 0.7692962288856506)]

# %%
new_t_model.wv.most_similar_cosmul(positive=['god', 'woman'], negative=['man'])
# Out:
# [('saints', 1.0426589250564575),
#  ('abraham', 1.0330098867416382),
#  ('testimony', 1.004754662513733),
#  ('isaac', 1.0020802021026611),
#  ('harlots', 0.971365213394165),
#  ('holy', 0.9590107798576355),
#  ('living', 0.9532079696655273),
#  ('favour', 0.9443594813346863),
#  ('sanctuary', 0.942393958568573),
#  ('anointed', 0.9304980635643005)]

# %%
quran_model.wv.most_similar_cosmul(positive=['god', 'woman'], negative=['man'])
# Out:
# [('unite', 0.9478878378868103),
#  ('besides', 0.9236583113670349),
#  ('absolute', 0.922363817691803),
#  ('unless', 0.9220916032791138),
#  ('protectors', 0.9211087822914124),
#  ('numerous', 0.9204667210578918),
#  ('whichever', 0.9173927903175354),
#  ('allotted', 0.9169683456420898),
#  ('calling', 0.9095615744590759),
#  ('helper', 0.909220814704895)]

# %% [markdown]
# ## How can we make this more accurate interesting?
#
# One way is to, instead of relying purely on the text and word similarities, is create a topic model and base the VSM off of that. Based on an input word, determine the topic it is most liklely to fall under, and then show back the most relevant topics. Also converting all words and input into their lemmas to avoid grammatical issues.
#
# Next steps:
# 1.

# %% [markdown]
# ## Data formatting and export
# Create a list of sample words and export a csv of their context for each.

# %%
# Create a JSON file of all of the data!
# These are just most similar words.
# Can also create a file of sample algebra.
de = {}
test_words = ["peace","man","woman","child","love","hate","war","marriage"]
for w in test_words:
    de[w] = {}
    de[w]["old_t"] = old_t_model.wv.most_similar (positive=w)
    de[w]["new_t"] = new_t_model.wv.most_similar (positive=w)
    de[w]["quran"] = quran_model.wv.most_similar (positive=w)

# %%
de
# Out:
# {'child': {'new_t': [('haste', 0.7561442852020264),
#    ('napkin', 0.7439369559288025),
#    ('damsel', 0.7335579991340637),
#    ('lifted', 0.7298068404197693),
#    ('charger', 0.7209768891334534),
#    ('looked', 0.7202779054641724),
#    ('receipt', 0.7172028422355652),
#    ('philip', 0.7126420736312866),
#    ('trembling', 0.7096721529960632),
#    ('saul', 0.7041950225830078)],
#   'old_t': [('woman', 0.7549619078636169),
#    ('damsel', 0.7061505317687988),
#    ('husband', 0.6856222152709961),
#    ('reapers', 0.6712771058082581),
#    ('she', 0.6696698665618896),
#    ('rebekah', 0.6502548456192017),
#    ('tamar', 0.646457314491272),
#    ('dead', 0.6433014869689941),
#    ('amnon', 0.6334642171859741),
#    ('naomi', 0.6255475282669067)],
#   'quran': [('sister', 0.8970965147018433),
#    ('husband', 0.8916230201721191),
#    ('weaning', 0.8584035038948059),
#    ('babe', 0.8578667044639587),
#    ('aloud', 0.8519386649131775),
#    ('re', 0.8485289812088013),
#    ('heir', 0.8365462422370911),
#    ('leaving', 0.8280004262924194),
#    ('prison', 0.8166272640228271),
#    ('suckle', 0.8123176097869873)]},
#  'hate': {'new_t': [('mammon', 0.8790050148963928),
#    ('forgive', 0.87107253074646),
#    ('despise', 0.8652114868164062),
#    ('falsely', 0.8607621788978577),
#    ('partner', 0.8552512526512146),
#    ('serve', 0.8490924835205078),
#    ('perhaps', 0.8475543260574341),
#    ('gird', 0.845697820186615),
#    ('lend', 0.8440867066383362),
#    ('unworthy', 0.8417739868164062)],
#   'old_t': [('teach', 0.6272773742675781),
#    ('abhor', 0.5997352600097656),
#    ('despise', 0.5928627252578735),
#    ('devise', 0.5888205170631409),
#    ('condemn', 0.5824639797210693),
#    ('oppress', 0.5742282867431641),
#    ('shew', 0.5738195180892944),
#    ('befall', 0.5733416676521301),
#    ('overtake', 0.5726547837257385),
#    ('slay', 0.572502613067627)],
#   'quran': [('instruction', 0.8673341274261475),
#    ('ours', 0.8565479516983032),
#    ('enacted', 0.8446544408798218),
#    ('proclaim', 0.8414639830589294),
#    ('undoubtedly', 0.8406023383140564),
#    ('statement', 0.8315833806991577),
#    ('forbear', 0.8228752017021179),
#    ('realise', 0.8224503397941589),
#    ('beareth', 0.8197979927062988),
#    ('imbecile', 0.8184643983840942)]},
#  'love': {'new_t': [('serve', 0.8119258880615234),
#    ('commandments', 0.7856768369674683),
#    ('keep', 0.7785295248031616),
#    ('knowledge', 0.7719000577926636),
#    ('fulfil', 0.7683531641960144),
#    ('beloved', 0.7623270153999329),
#    ('always', 0.760434627532959),
#    ('bear', 0.7556785941123962),
#    ('proof', 0.7545301914215088),
#    ('mammon', 0.7482309341430664)],
#   'old_t': [('delight', 0.7257524132728577),
#    ('forget', 0.6697789430618286),
#    ('commandments', 0.6665922999382019),
#    ('remember', 0.6421708464622498),
#    ('statutes', 0.6404740810394287),
#    ('thoughts', 0.6379579305648804),
#    ('judgments', 0.6192585229873657),
#    ('despise', 0.6143428087234497),
#    ('seek', 0.6072486042976379),
#    ('desire', 0.5918932557106018)],
#   'quran': [('practise', 0.78284752368927),
#    ('need', 0.7774329781532288),
#    ('associating', 0.7755076289176941),
#    ('restraint', 0.7718445062637329),
#    ('prosper', 0.7682269215583801),
#    ('thanks', 0.7649023532867432),
#    ('ignorant', 0.7622948288917542),
#    ('orphans', 0.759797215461731),
#    ('regard', 0.7505347728729248),
#    ('foremost', 0.7474765181541443)]},
#  'man': {'new_t': [('thing', 0.6594159007072449),
#    ('case', 0.628496527671814),
#    ('heir', 0.5895386338233948),
#    ('infidel', 0.5599852204322815),
#    ('himself', 0.5515251755714417),
#    ('idolater', 0.5453124642372131),
#    ('more', 0.5399671792984009),
#    ('save', 0.5371427536010742),
#    ('understandeth', 0.5229541659355164),
#    ('sufficient', 0.5201311111450195)],
#   'old_t': [('thing', 0.5546713471412659),
#    ('male', 0.5509366989135742),
#    ('one', 0.5310702323913574),
#    ('fool', 0.5202324986457825),
#    ('aholiab', 0.48265838623046875),
#    ('woman', 0.47498229146003723),
#    ('person', 0.46586424112319946),
#    ('neighbour', 0.45424652099609375),
#    ('creature', 0.4451093077659607),
#    ('fowl', 0.4434379041194916)],
#   'quran': [('woman', 0.7418229579925537),
#    ('person', 0.7216151356697083),
#    ('single', 0.6828794479370117),
#    ('she', 0.6717727184295654),
#    ('avowed', 0.6698634028434753),
#    ('seduce', 0.6692872643470764),
#    ('one', 0.6656155586242676),
#    ('beget', 0.6557849049568176),
#    ('unchaste', 0.6540983319282532),
#    ('exercise', 0.650551438331604)]},
#  'marriage': {'new_t': [('testament', 0.8535803556442261),
#    ('ripe', 0.8270993828773499),
#    ('less', 0.8074337840080261),
#    ('invisible', 0.8060460686683655),
#    ('elect', 0.798071563243866),
#    ('last', 0.7979719042778015),
#    ('sown', 0.7977509498596191),
#    ('mystery', 0.7958735227584839),
#    ('adam', 0.7939164042472839),
#    ('theirs', 0.7928258776664734)],
#   'old_t': [('loving', 0.8498883247375488),
#    ('eve', 0.8497138619422913),
#    ('laboureth', 0.841971755027771),
#    ('gathrimmon', 0.8383175730705261),
#    ('malcham', 0.8371787667274475),
#    ('shubael', 0.8212587237358093),
#    ('condemneth', 0.8185698986053467),
#    ('shuhamites', 0.8185401558876038),
#    ('reu', 0.8184724450111389),
#    ('keros', 0.818000078201294)],
#   'quran': [('writing', 0.9285460114479065),
#    ('maintenance', 0.9220064878463745),
#    ('support', 0.9072032570838928),
#    ('flog', 0.9050097465515137),
#    ('bond', 0.8985353112220764),
#    ('middle', 0.8957507610321045),
#    ('lower', 0.8946830034255981),
#    ('ties', 0.8932483792304993),
#    ('silver', 0.8932350873947144),
#    ('impure', 0.8911339044570923)]},
#  'peace': {'new_t': [('amen', 0.7101768851280212),
#    ('raise', 0.708192765712738),
#    ('sins', 0.7040704488754272),
#    ('stead', 0.6648786067962646),
#    ('propitiation', 0.6645596623420715),
#    ('rule', 0.6599134206771851),
#    ('visit', 0.6499534249305725),
#    ('separate', 0.640852153301239),
#    ('ours', 0.6406799554824829),
#    ('forgiveness', 0.640188992023468)],
#   'old_t': [('sacrifice', 0.5903193950653076),
#    ('sacrifices', 0.4953738749027252),
#    ('cost', 0.49304473400115967),
#    ('vows', 0.475742369890213),
#    ('offerings', 0.4731377065181732),
#    ('pleasure', 0.45949000120162964),
#    ('supplication', 0.44403180480003357),
#    ('burnt', 0.43745312094688416),
#    ('soul', 0.42893123626708984),
#    ('prayer', 0.428428053855896)],
#   'quran': [('salutation', 0.9123638868331909),
#    ('answered', 0.8301668763160706),
#    ('unblest', 0.813407301902771),
#    ('represent', 0.7855291962623596),
#    ('festival', 0.7760887742042542),
#    ('yes', 0.7757213711738586),
#    ('rebuke', 0.7614662051200867),
#    ('replied', 0.7572892904281616),
#    ('always', 0.7465890645980835),
#    ('yea', 0.7400630116462708)]},
#  'war': {'new_t': [('portion', 0.8857582211494446),
#    ('smite', 0.8773797750473022),
#    ('apt', 0.8701459765434265),
#    ('bill', 0.8684801459312439),
#    ('hospitality', 0.8640297651290894),
#    ('hyssop', 0.8591428399085999),
#    ('covenanted', 0.8581976294517517),
#    ('buffet', 0.8510793447494507),
#    ('footstool', 0.8507358431816101),
#    ('rod', 0.8506298661231995)],
#   'old_t': [('battle', 0.7353736758232117),
#    ('warriors', 0.6223754286766052),
#    ('fight', 0.6121992468833923),
#    ('syrians', 0.6058142185211182),
#    ('weapons', 0.6016030311584473),
#    ('armed', 0.5775481462478638),
#    ('hagarites', 0.5583223104476929),
#    ('army', 0.5549781918525696),
#    ('thousand', 0.542361319065094),
#    ('chariots', 0.5338828563690186)],
#   'quran': [('year', 0.9111289978027344),
#    ('bequest', 0.901901125907898),
#    ('hunger', 0.8985102772712708),
#    ('spreading', 0.8881351947784424),
#    ('entrusted', 0.8869273066520691),
#    ('four', 0.8868716955184937),
#    ('foot', 0.8853537440299988),
#    ('devour', 0.8849551677703857),
#    ('middle', 0.8813043236732483),
#    ('intoxicants', 0.879097044467926)]},
#  'woman': {'new_t': [('husband', 0.7899871468544006),
#    ('she', 0.7745798826217651),
#    ('daughter', 0.7675806283950806),
#    ('age', 0.7577566504478455),
#    ('conceived', 0.73133784532547),
#    ('her', 0.7228211760520935),
#    ('martha', 0.7181917428970337),
#    ('case', 0.6825310587882996),
#    ('damsel', 0.6750237941741943),
#    ('dorcas', 0.6532546281814575)],
#   'old_t': [('husband', 0.7593774795532227),
#    ('child', 0.7549619078636169),
#    ('damsel', 0.6976274847984314),
#    ('she', 0.695109486579895),
#    ('maid', 0.6652546525001526),
#    ('womb', 0.652423620223999),
#    ('betrothed', 0.6388161778450012),
#    ('carnally', 0.6270275712013245),
#    ('travail', 0.6183370351791382),
#    ('herself', 0.6178828477859497)],
#   'quran': [('deceased', 0.8420812487602234),
#    ('unbeliever', 0.8378864526748657),
#    ('wishes', 0.832939624786377),
#    ('husband', 0.827845573425293),
#    ('slave', 0.8241152763366699),
#    ('ascendants', 0.8100987672805786),
#    ('unbelieving', 0.8032357096672058),
#    ('believer', 0.801554262638092),
#    ('inheritance', 0.795785665512085),
#    ('single', 0.7896137833595276)]}}

# %%
with open('test_result_1.json', 'w') as fp:
    json.dump(de, fp)
